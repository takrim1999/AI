# %% [markdown]
# <a href="https://www.kaggle.com/code/takrimulalam/machinelearningusingpython-ipynb?scriptVersionId=255077027" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # This is a notebook to track all my exercises on the book [Machine Learning Using Python](https://read.amazon.in/sample/B07RLQPNRX?clientId=share&asin=B07RLQPNRX&revisionId=&format=4&depth=1) by [Manaranjan Pradhan](https://www.manaranjanp.com/)
#
# ## 1. [Pandas Practice NoteBook](https://www.kaggle.com/code/takrimulalam/practicing-pandas-with-ipl-auction-dataset-ipynb)
