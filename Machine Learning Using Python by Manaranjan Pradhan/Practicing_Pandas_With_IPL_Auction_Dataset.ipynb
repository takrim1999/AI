# %% [markdown]
# <a href="https://www.kaggle.com/code/takrimulalam/practicing-pandas-with-ipl-auction-dataset-ipynb?scriptVersionId=255299260" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ### Import Section

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Reading the dataset with pandas.
#     There are some methods to read datasets.
#         1. read_csv: to read CSV files
#         2. read_json: to read JSON files
#         3. read_fwf: to read data with fixed width format (new for me)
#         4. read_excel: to read Excel files
#         5. read_table: to read database tables

# %%
ipl_auction_df = pd.read_csv('/kaggle/input/ipl-dataset/IPL IMB381IPL2013.csv',index_col=0)
ipl_auction_df.head(5)
# Out:
#          PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# Sl.NO.
# 1        Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 2       Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 3        Agarkar, AB    2     IND   KKR       Bowler     571      58
# 4          Ashwin, R    1     IND   CSK       Bowler     284      31
# 5       Badrinath, S    2     IND   CSK      Batsman      63       0
#
#         ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ...    SR-B  SIXERS  RUNS-C  WKTS  \
# Sl.NO.                                  ...
# 1                0      0.00         0  ...    0.00       0     307    15
# 2              657     71.41       185  ...    0.00       0      29     0
# 3             1269     80.62       288  ...  121.01       5    1059    29
# 4              241     84.56        51  ...   76.32       0    1125    49
# 5               79     45.93         0  ...  120.71      28       0     0
#
# ...

# %% [markdown]
# ### We can check a method parameters by typing pandas.\<method\>?
# that's how I discovered the read_csv(index_col=) by typing: pd.read_csv?

# %% [markdown]
# ### Let's find the summery of our dataframe

# %%
columns = list(ipl_auction_df.columns)

# %% [markdown]
# ### There's a new for me large dataset viewing method
# by transposing the head(5) of dataframe

# %%
ipl_auction_df.head(5).transpose()
# Out:
# Sl.NO.                   1             2            3          4             5
# PLAYER NAME    Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R  Badrinath, S
# AGE                      2             2            2          1             2
# COUNTRY                 SA           BAN          IND        IND           IND
# TEAM                  KXIP           RCB          KKR        CSK           CSK
# PLAYING ROLE    Allrounder        Bowler       Bowler     Bowler       Batsman
# T-RUNS                   0           214          571        284            63
# T-WKTS                   0            18           58         31             0
# ODI-RUNS-S               0           657         1269        241            79
# ODI-SR-B               0.0         71.41        80.62      84.56         45.93
# ODI-WKTS                 0           185          288         51             0
# ODI-SR-BL              0.0          37.6         32.9       36.8           0.0
# ...

# %% [markdown]
# ### Let's check the shape, information

# %%
print(ipl_auction_df.shape)
print(ipl_auction_df.info())
# Out:
# (130, 25)
# <class 'pandas.core.frame.DataFrame'>
# Index: 130 entries, 1 to 130
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PLAYER NAME    130 non-null    object
#  1   AGE            130 non-null    int64
#  2   COUNTRY        130 non-null    object
#  3   TEAM           130 non-null    object
#  4   PLAYING ROLE   130 non-null    object
#  5   T-RUNS         130 non-null    int64
#  6   T-WKTS         130 non-null    int64
#  7   ODI-RUNS-S     130 non-null    int64
#  8   ODI-SR-B       130 non-null    float64
#  9   ODI-WKTS       130 non-null    int64
#  10  ODI-SR-BL      130 non-null    float64
#  11  CAPTAINCY EXP  130 non-null    int64
#  12  RUNS-S         130 non-null    int64
#  13  HS             130 non-null    int64
#  14  AVE            130 non-null    float64
#  15  SR-B           130 non-null    float64
#  16  SIXERS         130 non-null    int64
# ...

# %% [markdown]
# ### Slicing

# %%
ipl_auction_df[['PLAYER NAME','AGE']][:5]
# Out:
#          PLAYER NAME  AGE
# Sl.NO.
# 1        Abdulla, YA    2
# 2       Abdur Razzak    2
# 3        Agarkar, AB    2
# 4          Ashwin, R    1
# 5       Badrinath, S    2

# %% [markdown]
# ### Specific slicing

# %%
ipl_auction_df.iloc[5:10, 5:7]
# Out:
#         T-RUNS  T-WKTS
# Sl.NO.
# 6            0       0
# 7           51      27
# 8           54      50
# 9           83      17
# 10        5515       1

# %% [markdown]
# ### Value counts

# %%
ipl_auction_df.COUNTRY.value_counts()
# Out:
# COUNTRY
# IND    53
# AUS    22
# SA     16
# SL     12
# PAK     9
# NZ      7
# WI      6
# ENG     3
# BAN     1
# ZIM     1
# Name: count, dtype: int64

# %% [markdown]
# ### Finding the persons sold at base price :(

# %%
ipl_auction_df[ipl_auction_df['BASE PRICE'] == ipl_auction_df['SOLD PRICE']]
# Out:
#             PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# Sl.NO.
# 1           Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 2          Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 6            Bailey, GJ    2     AUS   CSK      Batsman       0       0
# 11            Bravo, DJ    2      WI   MI+   Allrounder    2200      86
# 12       Chanderpaul, S    3      WI   RCB      Batsman    9918       9
# 20          Duminy, J-P    2      SA   MI+      Batsman     654      11
# 21          Edwards, FH    2      WI    DC       Bowler     380     157
# 22        Fernando, CRD    2      SL    MI       Bowler     249      97
# 23          Fleming, SP    3      NZ   CSK      Batsman    7172       0
# 35        Henriques, MC    1     AUS  KKR+   Allrounder       0       0
# 39          Hussey, MEK    3     AUS   CSK      Batsman    5708       7
# 41            Jaffer, W    2     IND   RCB   Allrounder    1944       2
# ...
